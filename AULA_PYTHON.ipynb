# %% [markdown]
# <a href="https://colab.research.google.com/github/1205jo/Python/blob/main/AULA_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Aula 1** ❤ ☘ ♠

# %%
print("I competição de programação dá Start")
ano = "IX"
print(f"{ano} competição de programação da Start")
# Out:
# I competição de programação dá Start
# IX competição de programação da Start

# %% [markdown]
# #**Aula2** ✈ ⚰ ☣

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 5 * livro_infantil
pontos_totais = pontos_rodrigo + pontos_ana
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais da Ana são {pontos_ana}")
print(f"Os pontos totais do Rodrigo e da Ana são {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais da Ana são 46
# Os pontos totais do Rodrigo e da Ana são 70

# %% [markdown]
# #**Aula3 Tabuada** ☪ ⚕ ☠

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# #**Aula4 IMC** ✝ ☦ ✳

# %%
peso = float(input("Digite seu peso (em kg): "))
altura = float(input("Digite sua altura (em metros): "))
imc = peso / (altura ** 2)
print(f"\nSeu IMC é: {imc:.2f}")
if imc < 18.5:
    print("Você está abaixo do peso.")
elif 18.5 <= imc < 25:
    print("Você está no peso ideal.")
elif 25 <= imc < 30:
    print("Você está com sobrepeso.")
else:
    print("Você está acima do peso.")
# Out:
# Digite seu peso (em kg): 5.2
# Digite sua altura (em metros): 1.65
#
# Seu IMC é: 1.91
# Você está abaixo do peso.

# %% [markdown]
# #**Aula5** ❄ ⚒ ⚔

# %%
print("Olá, sou seu assistente virtua, em que posso ajudar?")
nome = input("Digite seu nome: ")
resposta = input(f"Olá {nome}, qual tema você deseja conversar? Python, Javascript ou Matemática: ").lower()
if resposta == "python":
  print(f"Ótimo {nome}, vamos falar sobre Python. Python é uma linguagem de programação de alto nível, simples e fácil de aprender, muito usada em diversas áreas da tecnologia.\n")
if resposta == "javascript":
 print(f"Ótimo {nome}, vamos falar sobre Javascript. JavaScript é uma linguagem de programação leve e dinâmica, criada originalmente para tornar as páginas web interativas.\n")
if resposta == "matemática":
  print(f"Ótimo {nome}, vamos falar sobre Maremática. A Matemática é a ciência que estuda números, formas, medidas, estruturas e relações entre quantidades. Ela busca descrever e compreender padrões, além de resolver problemas de forma lógica e precisa.\n")
else:
  print(f"Que pena {nome}, não sei falar sobre esse assunto")
# Out:
# Olá, sou seu assistente virtua, em que posso ajudar?
# Digite seu nome: jo
# Olá jo, qual tema você deseja conversar? Python, Javascript ou Matemática: python
# Ótimo jo, vamos falar sobre Python. Python é uma linguagem de programação de alto nível, simples e fácil de aprender, muito usada em diversas áreas da tecnologia.
#
# Que pena jo, não sei falar sobre esse assunto

# %% [markdown]
# #**Aula6-Listas** ⚛ ☣ ☀

# %%
import random
dicas = [
  " Acredite no seu potencial e faça acontecer🚀!",
  " Cada novo dia é uma nova chance para recomeçar🌅",
  " Não espere pela oportunidade, crie-a🔧",
  " Você é mais forte do que imagina💪",
  " Pequenos passos também te levam longe👣",
  " A disciplina é o caminho para o sucesso🎯",
  " Mantenha o foco e elimine as distrações👀",
  " O que você faz hoje pode melhorar todos os seus amanhãs🌟",
  " Sempre há algo positivo em cada desafio🌈",
  " A jornada pode ser longa, mas a vitória vale a pena🏆",
]
while True:
  pedido = input("Digite 'dica' para receber uma dica ou 'sair' para encerrar \n ").lower()

  if pedido == "dica":
    dica = random.choice(dicas) # escolhe uma dica aleatória sair
    print(f"Dica: {dica} \n")
  elif pedido == "sair":
    print("Até a próxima! \n")
    break
  else:
    print("Comando inválido. Tente novamente. \n")
    break
# Out:
# Digite 'dica' para receber uma dica ou 'sair' para encerrar
#  dica
# Dica:  Não espere pela oportunidade, crie-a🔧
#
# Digite 'dica' para receber uma dica ou 'sair' para encerrar
#  dica
# Dica:  Você é mais forte do que imagina💪
#
# Digite 'dica' para receber uma dica ou 'sair' para encerrar
#  sair
# Até a próxima!
